# %% [markdown]
# <a href="https://colab.research.google.com/github/yaelrsc/Heart-Diseases-Prediction-Bayesian-Model-/blob/main/TanquedeIdeas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
db = pd.read_csv('cardio[1].csv')

# %%
db.head()
# Out:
#    Unnamed: 0  casos_1 control_0  edad_m  talla_m  peso_ant_emb  imc_ant_emb  \
# 0           0                  1      36     1.58          56.0    22.432303
# 1           1                  1      26     1.66          64.0    23.225432
# 2           2                  1      31     1.69          78.0    27.309968
# 3           3                  1      31     1.55          82.0    34.131113
# 4           4                  1      35     1.52          51.5    22.290512
#
#   residencia  gesta  para  abortos_  ...  pescados_g  embutidos_g  \
# 0         DF      4     3         1  ...    12.85714     9.908666
# 1         DF      5     5         0  ...    61.61593    23.285720
# 2   Edo. Mex      3     1         1  ...   162.85710    40.714290
# 3   Edo. Mex      5     4         0  ...    64.28572    26.142860
# 4   Edo. Mex      2     0         0  ...    89.33256    40.167450
#
#    carnesrojas_g leguminosas_g  cer_refinados_g  cer_ref_con_azucar_g  \
# ...

# %%
tipo_de_cc = db['tipo_de_cc'].value_counts()
tipo_de_cc  = 100*tipo_de_cc /tipo_de_cc .sum()
plt.figure(figsize=(8,6))
plt.xticks(rotation=90)
plt.bar(list(tipo_de_cc.index),tipo_de_cc.values)
plt.show()
